# %% [markdown]
# <a href="https://colab.research.google.com/github/pravanjangarg20/tokyo-olympic-azure-data-engineer-project/blob/main/54_Parkinson_Deises.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import metrics

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score,confusion_matrix

# %%
df=pd.read_csv('parkinsons.data')

# %%
df
# Out:
#                name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  ...   spread2        D2       PPE
# 0    phon_R01_S01_1      119.992       157.302  ...  0.266482  2.301442  0.284654
# 1    phon_R01_S01_2      122.400       148.650  ...  0.335590  2.486855  0.368674
# 2    phon_R01_S01_3      116.682       131.111  ...  0.311173  2.342259  0.332634
# 3    phon_R01_S01_4      116.676       137.871  ...  0.334147  2.405554  0.368975
# 4    phon_R01_S01_5      116.014       141.781  ...  0.234513  2.332180  0.410335
# ..              ...          ...           ...  ...       ...       ...       ...
# 190  phon_R01_S50_2      174.188       230.978  ...  0.121952  2.657476  0.133050
# 191  phon_R01_S50_3      209.516       253.017  ...  0.129303  2.784312  0.168895
# 192  phon_R01_S50_4      174.688       240.005  ...  0.158453  2.679772  0.131728
# 193  phon_R01_S50_5      198.764       396.961  ...  0.207454  2.138608  0.123306
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              195 non-null    object
#  1   MDVP:Fo(Hz)       195 non-null    float64
#  2   MDVP:Fhi(Hz)      195 non-null    float64
#  3   MDVP:Flo(Hz)      195 non-null    float64
#  4   MDVP:Jitter(%)    195 non-null    float64
#  5   MDVP:Jitter(Abs)  195 non-null    float64
#  6   MDVP:RAP          195 non-null    float64
#  7   MDVP:PPQ          195 non-null    float64
#  8   Jitter:DDP        195 non-null    float64
#  9   MDVP:Shimmer      195 non-null    float64
#  10  MDVP:Shimmer(dB)  195 non-null    float64
#  11  Shimmer:APQ3      195 non-null    float64
#  12  Shimmer:APQ5      195 non-null    float64
#  13  MDVP:APQ          195 non-null    float64
#  14  Shimmer:DDA       195 non-null    float64
#  15  NHR               195 non-null    float64
# ...

# %%
df.describe()
# Out:
#        MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  ...     spread2          D2         PPE
# count   195.000000    195.000000    195.000000  ...  195.000000  195.000000  195.000000
# mean    154.228641    197.104918    116.324631  ...    0.226510    2.381826    0.206552
# std      41.390065     91.491548     43.521413  ...    0.083406    0.382799    0.090119
# min      88.333000    102.145000     65.476000  ...    0.006274    1.423287    0.044539
# 25%     117.572000    134.862500     84.291000  ...    0.174351    2.099125    0.137451
# 50%     148.790000    175.829000    104.315000  ...    0.218885    2.361532    0.194052
# 75%     182.769000    224.205500    140.018500  ...    0.279234    2.636456    0.252980
# max     260.105000    592.030000    239.170000  ...    0.450493    3.671155    0.527367
#
# [8 rows x 23 columns]

# %%
df.columns
# Out:
# Index(['name', 'MDVP:Fo(Hz)', 'MDVP:Fhi(Hz)', 'MDVP:Flo(Hz)', 'MDVP:Jitter(%)',
#        'MDVP:Jitter(Abs)', 'MDVP:RAP', 'MDVP:PPQ', 'Jitter:DDP',
#        'MDVP:Shimmer', 'MDVP:Shimmer(dB)', 'Shimmer:APQ3', 'Shimmer:APQ5',
#        'MDVP:APQ', 'Shimmer:DDA', 'NHR', 'HNR', 'status', 'RPDE', 'DFA',
#        'spread1', 'spread2', 'D2', 'PPE'],
#       dtype='object')

# %% [markdown]
# ## Visulization

# %%
plt.figure(figsize=(10,6))
df.status.hist()
plt.xlabel('Status')
plt.ylabel('Frequency')
plt.plot()
# Out:
# []

# %%
plt.figure(figsize=(10,6))
sns.barplot(data=df,x='status',y='HNR')
# Out:
# <Axes: xlabel='status', ylabel='HNR'>

# %%
plt.figure(figsize=(10,6))
sns.barplot(data=df,x='status',y='RPDE')
# Out:
# <Axes: xlabel='status', ylabel='RPDE'>

# %% [markdown]
# ###Distribution Plot

# %%
rows=3
cols=7
fig,ax=plt.subplots(nrows=rows,ncols=cols,figsize=(16,4))
col=df.columns
index=1
for i in range(rows):
  for j in range(cols):
    sns.distplot(df[col[index]],ax=ax[i][j])
    index+=1
plt.tight_layout
# Out:
# <ipython-input-12-0216b55ebfe0>:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[col[index]],ax=ax[i][j])
# <ipython-input-12-0216b55ebfe0>:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[col[index]],ax=ax[i][j])
# ...

# %%
df.drop(['name'],axis=1,inplace=True)

# %%
X=df.drop(labels=['status'],axis=1)
y=df['status']
X.head()
# Out:
#    MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  ...   spread1   spread2        D2       PPE
# 0      119.992       157.302        74.997         0.00784  ... -4.813031  0.266482  2.301442  0.284654
# 1      122.400       148.650       113.819         0.00968  ... -4.075192  0.335590  2.486855  0.368674
# 2      116.682       131.111       111.555         0.01050  ... -4.443179  0.311173  2.342259  0.332634
# 3      116.676       137.871       111.366         0.00997  ... -4.117501  0.334147  2.405554  0.368975
# 4      116.014       141.781       110.655         0.01284  ... -3.747787  0.234513  2.332180  0.410335
#
# [5 rows x 22 columns]

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=40)
print(X_train.shape,X_test.shape,y_train.shape,y_test.shape)
# Out:
# (156, 22) (39, 22) (156,) (39,)

# %% [markdown]
# #Machine Learning

# %% [markdown]
# ### Logistic Regression

# %%
log_reg=LogisticRegression()
log_reg.fit(X_train,y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
train_pres=log_reg.predict(X_train)
test_pres=log_reg.predict(X_test)

# %%
print('Logistic Regression model train accuracy is: ',accuracy_score(y_train,train_pres))
print('Logistic Regression model test accuracy is: ',accuracy_score(y_test,test_pres))
print('Confusion matrix train is: ', confusion_matrix(y_train,train_pres))
print('Confusion matrix test is: ', confusion_matrix(y_test,test_pres))
# Out:
# Logistic Regression model train accuracy is:  0.8717948717948718
# Logistic Regression model test accuracy is:  0.8717948717948718
# Confusion matrix train is:  [[ 25  15]
#  [  5 111]]
# Confusion matrix test is:  [[ 5  3]
#  [ 2 29]]

# %%
RF=RandomForestClassifier()
RF.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
train_pres1=RF.predict(X_train)
test_pres1=RF.predict(X_test)
print('Random Forest model train accuracy is: ',accuracy_score(y_train,train_pres1))
print('Random Forest model test accuracy is: ',accuracy_score(y_test,test_pres1))
print('Confusion matrix train is: ', confusion_matrix(y_train,train_pres1))
print('Confusion matrix test is: ', confusion_matrix(y_test,test_pres1))
# Out:
# Random Forest model train accuracy is:  1.0
# Random Forest model test accuracy is:  0.8461538461538461
# Confusion matrix train is:  [[ 40   0]
#  [  0 116]]
# Confusion matrix test is:  [[ 5  3]
#  [ 3 28]]
